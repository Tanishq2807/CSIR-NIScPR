# %%
import pandas as pd
import numpy as np
import statsmodels.api as sm
from factor_analyzer.rotator import Rotator
from concurrent.futures import ProcessPoolExecutor
import os

# %%
df_all = pd.read_csv('/Users/tanishq/PycharmProjects/NIScPR/FinTech/DerwentData_TS/ml/MainData.csv')
col = df_all['Application Date'].astype(str).str.strip().replace({'': pd.NA, 'nan': pd.NA})
dt = pd.to_datetime(col, format='mixed', dayfirst=True, errors='coerce')

df_all['Application Date'] = dt
df_all = df_all[(df_all['Application Date'] >= '2023-01-01') & (df_all['Application Date'] <= '2024-12-31')]


# df_ml = pd.read_csv('FinTech3OutputADA.csv')
df_ml = pd.read_csv('FinTech3OutputADA.csv')
df_ml = df_ml[df_ml['High Quality'] == 1]

df_sem = pd.read_csv('QualityIndex(23-24)_3.csv')
threshold = df_sem['Quality Index'].quantile(0.95)
df_sem = df_sem[df_sem['Quality Index'] > threshold]

# %%
df_all.shape
# Out:
# (9823, 19)

# %%
df_sem
# Out:
#     Publication Number Application Date Publication Date IPC Subclass  \
# 0      US20230251797A1       2023-03-27       2023-08-10         G06F
# 1         US12282686B2       2023-03-27       2025-04-22         G06F
# 2      US20230252165A1       2023-03-29       2023-08-10         G06F
# 3         US12204657B2       2023-03-29       2025-01-21         G06F
# 4      US20240028748A1       2023-08-14       2024-01-25         G06F
# ..                 ...              ...              ...          ...
# 484    US20240242215A1       2023-01-13       2024-07-18         G06Q
# 485    US20230422320A1       2023-09-11       2023-12-28         H04W
# 486       US12232191B2       2023-09-11       2025-02-18         H04W
# 487    US20240394049A1       2024-07-31       2024-11-28         G06F
# 488    US20230247676A1       2023-04-07       2023-08-03  H04W | H04L
#
#      Assignee - Original Assignee Standardized  Claims Count  Assignee Count  \
# 0      PURE STORAGE INC.      PURE STORAGE INC          20.0               1
# 1      PURE STORAGE INC.      PURE STORAGE INC          17.0               2
# 2      Pure Storage Inc.      PURE STORAGE INC          20.0               1
# 3      Pure Storage Inc.      PURE STORAGE INC          16.0               2
# 4      Pure Storage Inc.      PURE STORAGE INC          20.0               1
# ..                   ...                   ...           ...             ...
# 484      NCR Corporation       NCR CORPORATION          20.0               1
# 485  LG Electronics Inc.    LG ELECTRONICS INC           6.0               1
# 486  LG Electronics Inc.    LG ELECTRONICS INC           6.0               2
# 487    Pure Storage Inc.      PURE STORAGE INC          20.0               1
# 488  LG ELECTRONICS INC.    LG ELECTRONICS INC           8.0               2
#
#                                    Inventor - Original  \
# 0    KANNAN, HARI | FEIGIN, BORIS | GAO, YING | COL...
# 1    Kannan, Hari | Feigin, Boris | Gao, Ying | Col...
# 2      De’souza, Ajay | Phadke, Sandeep | Karr, Ronald
# 3       D'Souza, Ajay | Phadke, Sandeep | Karr, Ronald
# 4    Marcon, Paulo | Gelinger Maciel, Romulo | Karr...
# ..                                                 ...
# 484                                Nonni, Bryan Walser
# 485                    YOUN, Myungjune | KIM, Hyunsook
# 486                    Youn, Myungjune | Kim, Hyunsook
# 487  Vohra, Taher | Prakashaiah, Virendra | Pabón, ...
# 488     SHIN, Seokmin | KIM, Seonwook | YANG, Suckchel
#
#                                  Inventor Standardized  \
# 0    KANNAN HARI | FEIGIN BORIS | GAO YING | COLGRO...
# 1    KANNAN HARI | FEIGIN BORIS | GAO YING | COLGRO...
# 2          DESOUZA AJAY | PHADKE SANDEEP | KARR RONALD
# 3           DSOUZA AJAY | PHADKE SANDEEP | KARR RONALD
# 4    MARCON PAULO | GELINGER MACIEL ROMULO | KARR R...
# ..                                                 ...
# 484                                 NONNI BRYAN WALSER
# 485                      YOUN MYUNGJUNE | KIM HYUNSOOK
# 486                      YOUN MYUNGJUNE | KIM HYUNSOOK
# 487  VOHRA TAHER | PRAKASHAIAH VIRENDRA | PABÓN LUI...
# 488        SHIN SEOKMIN | KIM SEONWOOK | YANG SUCKCHEL
#
#     Publication Country Code  Count of Cited Refs - Patent  Inventor Count  \
# 0                         US                           898               4
# 1                         US                           898               4
# 2                         US                           680               3
# 3                         US                           680               3
# 4                         US                           654               3
# ..                       ...                           ...             ...
# 484                       US                            11               1
# 485                       US                            11               2
# 486                       US                            11               2
# 487                       US                            18               3
# 488                       US                             6               3
#
#      IPC Count  Count of Cited Refs - Non-patent  Count of Citing Patents  \
# 0            1                                67                        2
# 1            1                                67                        0
# 2            1                                11                        1
# 3            1                                11                        0
# 4            1                                11                        1
# ..         ...                               ...                      ...
# 484          1                                 3                        0
# 485          1                                 3                        0
# 486          1                                 3                        0
# 487          1                                 0                        1
# 488          1                                 5                        5
#
#      DWPI Count of Family Members  DWPI Count of Family Countries/Regions  \
# 0                             2.0                                     1.0
# 1                             2.0                                     1.0
# 2                            60.0                                   139.0
# 3                            60.0                                   139.0
# 4                            60.0                                   139.0
# ..                            ...                                     ...
# 484                           1.0                                     1.0
# 485                           9.0                                   136.0
# 486                           9.0                                   136.0
# 487                           2.0                                     1.0
# 488                           8.0                                   136.0
#
#      Legal Years Remaining  Quality Index
# 0                        5     310.112331
# 1                        5     310.081979
# 2                       14     207.360969
# 3                       14     207.345793
# 4                       14     199.723703
# ..                     ...            ...
# 484                     18       5.304400
# 485                     15       5.304400
# 486                     15       5.304400
# 487                     16       5.302514
# 488                     15       5.293741
#
# [489 rows x 20 columns]

# %%
# df_ml = df_ml[df_ml['High Quality'] == 1]
df_ml
# Out:
#       Unnamed: 0 Publication Number Application Date Publication Date  \
# 725          725    US20240333522A1       2024-06-07       2024-10-03
# 1514        1514       CN117874733B       2024-03-12       2024-05-24
# 1515        1515       CN117874733A       2024-03-12       2024-04-12
# 1823        1823    US20240261692A1       2024-01-30       2024-08-08
# 2332        2332    US20240160361A1       2023-11-29       2024-05-16
# ...          ...                ...              ...              ...
# 9750       29266       US12271359B2       2023-03-01       2025-04-08
# 9783       29299       US12395960B2       2023-01-31       2025-08-19
# 9795       29311       US12412213B2       2023-01-19       2025-09-09
# 9810       29326       US12314134B2       2023-01-09       2025-05-27
# 9816       29332       US12356486B2       2023-01-05       2025-07-08
#
#             IPC Subclass                       Assignee Standardized  \
# 725                 H04L  RUTGERS THE STATE UNIVERSITY OF NEW JERSEY
# 1514         G06F | G06Q     BEIJING YINGJIA BRAND MANAGEMENT CO LTD
# 1515         G06F | G06Q     BEIJING YINGJIA BRAND MANAGEMENT CO LTD
# 1823         A63F | H04L                        VERONA HOLDINGS SEZC
# 2332                G06F                            PURE STORAGE INC
# ...                  ...                                         ...
# 9750                G06F                            PURE STORAGE INC
# 9783                H04W                          LG ELECTRONICS INC
# 9795  G06Q | G06F | G06N                          EXEGY INCORPORATED
# 9810                G06F                            PURE STORAGE INC
# 9816         H04W | H04B                          LG ELECTRONICS INC
#
#       Claims Count  Assignee Count  \
# 725           20.0               1
# 1514           7.0               1
# 1515          10.0               1
# 1823          20.0               2
# 2332          20.0               1
# ...            ...             ...
# 9750          20.0               2
# 9783          15.0               2
# 9795          41.0               2
# 9810          18.0               2
# 9816           8.0               2
#
#                                   Inventor Standardized  \
# 725    MINSKY NAFTALY H | CONG CHEN | ZIMMERMAN DAVID M
# 1514                                       CHEN SHU CUI
# 1515                                       CHEN SHU CUI
# 1823  SLIWKA LUKASZ JAKUB | QUIGLEY WILLIAM EDWARD |...
# 2332                                        KARR RONALD
# ...                                                 ...
# 9750  KANNAN HARI | GAO YING | FEIGIN BORIS | LEE RO...
# 9783                        JUNG SUNGHOON | KIM HONGSUK
# 9795  TAYLOR DAVID EDWARD | LEE ANDY YOUNG | SCHUEHL...
# 9810     KARR RONALD | NEELAKANTAM NAVEEN | JIBAJA IVAN
# 9816                                       YI SEUNGJUNE
#
#      Publication Country Code  Count of Cited Refs - Patent  \
# 725                        US                             8
# 1514                       CN                            14
# 1515                       CN                            14
# 1823                       US                             0
# 2332                       US                            24
# ...                       ...                           ...
# 9750                       US                           516
# 9783                       US                            17
# 9795                       US                           133
# 9810                       US                           204
# 9816                       US                            12
#
#       Count of Cited Refs - Non-patent  Count of Citing Patents  \
# 725                                 21                        0
# 1514                                12                        0
# 1515                                12                        0
# 1823                                 0                       30
# 2332                                27                        0
# ...                                ...                      ...
# 9750                                26                        0
# 9783                                 8                        0
# 9795                                22                        0
# 9810                                36                        0
# 9816                                 8                        0
#
#       DWPI Count of Family Members  DWPI Count of Family Countries/Regions  \
# 725                            5.0                                   134.0
# 1514                           2.0                                     1.0
# 1515                           2.0                                     1.0
# 1823                           1.0                                     1.0
# 2332                           2.0                                     1.0
# ...                            ...                                     ...
# 9750                           2.0                                     1.0
# 9783                           5.0                                   135.0
# 9795                           2.0                                     1.0
# 9810                           3.0                                   138.0
# 9816                           7.0                                   136.0
#
#       High Quality
# 725              1
# 1514             1
# 1515             1
# 1823             1
# 2332             1
# ...            ...
# 9750             1
# 9783             1
# 9795             1
# 9810             1
# 9816             1
#
# [137 rows x 16 columns]

# %%
# cols_to_keep = [
#     'Publication Number', 'Publication Date', 'Earliest Priority Year',
#     'Publication Country Code', 'Assignee Standardized',
#     'Inventor Standardized', 'IPC Subclass', 'Count of Cited Refs - Patent',
#     'Count of Cited Refs - Non-patent', 'Count of Citing Patents',
#     'DWPI Count of Family Members', 'Assignee Count', 'Inventor Count',
#     'Claims Count', 'Legal Years Remaining', 'IPC Count',
#     'DWPI Count of Family Countries/Regions', 'Application Date'
# ]
#
# df1 = pd.DataFrame()
# df1['Publication Number'] = df_ml['Publication Number']
# # Perform the merge
# result = df1.merge(
#     df_all[cols_to_keep],
#     on='Publication Number',   # join key
#     how='left'                 # or 'inner' if you only want exact matches
# )
# result.to_csv('TopML_3Indicators.csv', index=False)

# %%
import pandas as pd
import matplotlib.pyplot as plt
import textwrap
from collections import Counter

ipc_labels = {
    "H04W": "Wireless communication networks",
    "G06Q": "Data processing for admin/finance/commerce",
    "G06F": "Electric digital data processing (computers)",
    "H04L": "Transmission of digital information",
    "H04B": "Transmission (general)",
    "G06N": "Computer systems based on specific models (AI/NN etc.)",
    "G06V": "Image or video recognition / understanding",
    "G06K": "Recognition/presentation of data; record carriers",
    "G10L": "Speech analysis, synthesis, recognition",
    "H04N": "Pictorial communication (television, video)",
    "G06T": "Image data processing or generation (general)",
    "G01S": "Radio direction-finding, navigation, radar",
    "G07F": "Coin-freed/vending apparatus",
    "H04M": "Telephonic communication",
    "H04J": "Multiplex communication",
    "G08G": "Traffic control systems",
    "G16H": "Health informatics (ICT for healthcare)",
    "B60W": "Conjoint control of vehicle sub-units",
    "H03M": "Coding, decoding, or code conversion",
    "G07G": "Cash register / point-of-sale systems",
    "G07C": "Time/attendance; machine work logging; access/ID; fee/toll registers",
    "G01C": "Measuring distances, bearings; surveying; navigation; gyros; photogrammetry",
    "G05B": "Control or regulating systems in general; programmable/sequence controllers",
    "G07D": "Handling coins or paper currency; authenticity testing; cash/banknote processing",
    "G11B": "INFORMATION STORAGE BASED ON RELATIVE MOVEMENT BETWEEN RECORD CARRIER AND TRANSDUCER",
}

def plot_top_entities_combined(
    dfs: dict,
    column: str,
    k_per_record: int = 1,
    top_n: int = 20,
    wrap_width: int = 40,
    xlabel: str = "Number of Patents",
    ylabel: str = "Entity",
    title: str = "Top Entities Comparison",
    figsize=(14, 9),
    exclude=None,
    label_map=None,
    label_mode: str = "code+label",
    label_offset_frac: float = 0.04,   # 4% of bar width
    label_offset_min: float = 0.0      # at least this many units
):
    if not isinstance(dfs, dict) or len(dfs) == 0:
        raise ValueError("dfs must be a non-empty dict of name->DataFrame.")
    for name, df in dfs.items():
        if column not in df.columns:
            raise KeyError(f"Column '{column}' not in DataFrame '{name}'.")

    def top_k(entry: str) -> str:
        if not isinstance(entry, str):
            return ""
        parts = [x.strip() for x in entry.split(",") if x.strip()]
        return " | ".join(parts[:k_per_record]) if k_per_record > 0 else ""

    def wrap_labels(label: str) -> str:
        return "\n".join(textwrap.wrap(str(label), wrap_width)) if label else ""

    ex = set(exclude or set())

    # row-normalized counts
    count_dfs = []
    for name, df in dfs.items():
        df_tmp = df.copy()
        df_tmp[column + "_top"] = df_tmp[column].apply(top_k)

        counts = Counter()
        for entry in df_tmp[column + "_top"]:
            if isinstance(entry, str) and entry.strip():
                ents = {
                    ent.strip() for ent in entry.split("|")
                    if ent.strip() and ent.strip() not in ex
                }
                if ents:
                    w = 1.0 / len(ents)
                    for key in ents:
                        counts[key] += w

        count_df = pd.DataFrame(counts.items(), columns=[column, name])
        count_dfs.append(count_df)

    # merge and rank
    merged_counts = count_dfs[0]
    for df_ in count_dfs[1:]:
        merged_counts = pd.merge(merged_counts, df_, on=column, how="outer")
    merged_counts = merged_counts.fillna(0)

    value_cols = [c for c in merged_counts.columns if c != column]
    merged_counts["Total"] = merged_counts[value_cols].sum(axis=1)
    merged_counts = merged_counts.sort_values("Total", ascending=False).head(top_n).copy()

    # labels
    if label_map:
        def build_label(code: str) -> str:
            desc = label_map.get(code)
            return code if not desc else (desc if label_mode == "replace" else f"{code} – {desc}")
        merged_counts["label"] = merged_counts[column].map(build_label)
    else:
        merged_counts["label"] = merged_counts[column]
    merged_counts["wrapped"] = merged_counts["label"].apply(wrap_labels)

    # plot
    fig, ax = plt.subplots(figsize=figsize)
    y = range(len(merged_counts))
    n_series = max(1, len(dfs))
    height = 0.8 / n_series

    palette = plt.rcParams["axes.prop_cycle"].by_key().get("color", ["C0","C1","C2","C3","C4","C5"])
    colors = (palette * ((n_series // len(palette)) + 1))[:n_series]

    # global max to set xlim and compute a safe outer margin
    global_max = 0.0
    for name in dfs.keys():
        if name in merged_counts:
            global_max = max(global_max, float(merged_counts[name].max() or 0.0))
    xmax = global_max * 1.12 if global_max > 0 else 1.0
    ax.set_xlim(0, xmax)

    for i, (name, color) in enumerate(zip(list(dfs.keys()), colors)):
        vals = merged_counts[name].values if name in merged_counts else [0]*len(merged_counts)
        bars = ax.barh(
            [pos + i * height for pos in y],
            vals,
            height=height,
            label=name,
            color=color,
        )
        for bar in bars:
            w = bar.get_width()
            if w > 0:
                # adaptive label offset
                offset = max(label_offset_frac * w, label_offset_min)
                x_text = min(w + offset, xmax * 0.995)  # keep inside axes
                ax.text(
                    x_text,
                    bar.get_y() + bar.get_height() / 2,
                    f"{w:.2f}",
                    va="center",
                    ha="right" if x_text >= xmax * 0.99 else "left",
                    fontsize=8,
                )

    mid_offset = (n_series - 1) * height / 2
    ax.set_yticks([pos + mid_offset for pos in y], merged_counts["wrapped"], fontsize=8)

    ax.set_xlabel(xlabel, fontsize=12)
    ax.set_ylabel(ylabel, fontsize=12)
    ax.set_title(title, fontsize=14)
    ax.legend()
    ax.invert_yaxis()
    plt.xscale("symlog", linthresh=10)
    fig.tight_layout()
    plt.show()

    return merged_counts

# %%
plot_top_entities_combined(
    dfs={"All Patents (2023-24)": df_all, "High Quality Patents Predicted by SEM": df_sem, "High Quality Patents Predicted by ML": df_ml},
    column="Assignee Standardized",
    ylabel="Assignee",
    title="Top Assignees (3 Indicators)",
    k_per_record=1,
    top_n=20
)
# Out:
#                                   Assignee Standardized  \
# 844                                  LG ELECTRONICS INC
# 605     INDUSTRIAL AND COMMERCIAL BANK OF CHINA LIMITED
# 1110                  PINGAN TECHNOLOGY SHENZHEN CO LTD
# 1103  PING AN PROPERTY CASUALTY INSURANCE COMPANY OF...
# 1155                                   PURE STORAGE INC
# 1099                                PING AN BANK CO LTD
# 1102        PING AN LIFE INSURANCE COMPANY OF CHINA LTD
# 116                               BANK OF CHINA LIMITED
# 235                                  CCB FINTECH CO LTD
# 271                 CHINA CONSTRUCTION BANK CORPORATION
# 801                                      KT CORPORATION
# 1107                     PINGAN HEALTH INSURANCE CO LTD
# 1371                     SHENZHEN QIANHAI WEBANK CO LTD
# 227                            CAPITAL ONE SERVICES LLC
# 1101     PING AN INTERNATIONAL FINANCIAL LEASING CO LTD
# 35                   AGRICULTURAL BANK OF CHINA LIMITED
# 689                              JPMORGAN CHASE BANK NA
# 1112                 PINGAN YIQIANBAO E COMMERCE CO LTD
# 717     KANGJIAN INFORMATION TECHNOLOGY SHENZHEN CO LTD
# 627                       INTELLECTUAL DISCOVERY CO LTD
#
#       All Patents (2023-24)  High Quality Patents Predicted by SEM  \
# 844                  3430.0                                  238.5
# 605                  1720.0                                   14.0
# 1110                  574.5                                    0.0
# 1103                  510.0                                    0.0
# 1155                  300.0                                  118.0
# 1099                  338.0                                    2.0
# 1102                  264.0                                    0.0
# 116                   119.0                                    0.0
# 235                    99.5                                    4.0
# 271                    81.0                                    0.0
# 801                    71.0                                    1.0
# 1107                   62.0                                    0.0
# 1371                   57.0                                    0.0
# 227                    35.0                                   11.0
# 1101                   45.0                                    0.0
# 35                     43.0                                    0.0
# 689                    32.0                                    3.0
# 1112                   32.0                                    0.0
# 717                    30.0                                    0.0
# 627                    29.0                                    0.0
#
#       High Quality Patents Predicted by ML   Total  \
# 844                                   60.0  3728.5
# 605                                    0.0  1734.0
# 1110                                   0.0   574.5
# 1103                                   0.0   510.0
# 1155                                  53.0   471.0
# 1099                                   0.0   340.0
# 1102                                   0.0   264.0
# 116                                    0.0   119.0
# 235                                    0.0   103.5
# 271                                    0.0    81.0
# 801                                    0.0    72.0
# 1107                                   0.0    62.0
# 1371                                   0.0    57.0
# 227                                    4.0    50.0
# 1101                                   0.0    45.0
# 35                                     0.0    43.0
# 689                                    0.0    35.0
# 1112                                   0.0    32.0
# 717                                    0.0    30.0
# 627                                    0.0    29.0
#
#                                                   label  \
# 844                                  LG ELECTRONICS INC
# 605     INDUSTRIAL AND COMMERCIAL BANK OF CHINA LIMITED
# 1110                  PINGAN TECHNOLOGY SHENZHEN CO LTD
# 1103  PING AN PROPERTY CASUALTY INSURANCE COMPANY OF...
# 1155                                   PURE STORAGE INC
# 1099                                PING AN BANK CO LTD
# 1102        PING AN LIFE INSURANCE COMPANY OF CHINA LTD
# 116                               BANK OF CHINA LIMITED
# 235                                  CCB FINTECH CO LTD
# 271                 CHINA CONSTRUCTION BANK CORPORATION
# 801                                      KT CORPORATION
# 1107                     PINGAN HEALTH INSURANCE CO LTD
# 1371                     SHENZHEN QIANHAI WEBANK CO LTD
# 227                            CAPITAL ONE SERVICES LLC
# 1101     PING AN INTERNATIONAL FINANCIAL LEASING CO LTD
# 35                   AGRICULTURAL BANK OF CHINA LIMITED
# 689                              JPMORGAN CHASE BANK NA
# 1112                 PINGAN YIQIANBAO E COMMERCE CO LTD
# 717     KANGJIAN INFORMATION TECHNOLOGY SHENZHEN CO LTD
# 627                       INTELLECTUAL DISCOVERY CO LTD
#
#                                                 wrapped
# 844                                  LG ELECTRONICS INC
# 605    INDUSTRIAL AND COMMERCIAL BANK OF CHINA\nLIMITED
# 1110                  PINGAN TECHNOLOGY SHENZHEN CO LTD
# 1103  PING AN PROPERTY CASUALTY INSURANCE\nCOMPANY O...
# 1155                                   PURE STORAGE INC
# 1099                                PING AN BANK CO LTD
# 1102       PING AN LIFE INSURANCE COMPANY OF CHINA\nLTD
# 116                               BANK OF CHINA LIMITED
# 235                                  CCB FINTECH CO LTD
# 271                 CHINA CONSTRUCTION BANK CORPORATION
# 801                                      KT CORPORATION
# 1107                     PINGAN HEALTH INSURANCE CO LTD
# 1371                     SHENZHEN QIANHAI WEBANK CO LTD
# 227                            CAPITAL ONE SERVICES LLC
# 1101    PING AN INTERNATIONAL FINANCIAL LEASING\nCO LTD
# 35                   AGRICULTURAL BANK OF CHINA LIMITED
# 689                              JPMORGAN CHASE BANK NA
# 1112                 PINGAN YIQIANBAO E COMMERCE CO LTD
# 717    KANGJIAN INFORMATION TECHNOLOGY SHENZHEN\nCO LTD
# 627                       INTELLECTUAL DISCOVERY CO LTD

# %%
plot_top_entities_combined(
    dfs={"All Patents (2023-24)": df_all, "High Quality Patents Predicted by SEM": df_sem, "High Quality Patents Predicted by ML": df_ml},
    column="Inventor Standardized",
    ylabel="Inventor",
    title="Top Inventor (3 Indicators)",
    k_per_record=1,
    top_n=20
)
# Out:
#      Inventor Standardized  All Patents (2023-24)  \
# 3483          LEE SEUNGMIN             249.028571
# 8224         YANG SUCKCHEL             135.688095
# 3164          KIM SEONWOOK             134.466667
# 6001           SEO HANBYUL             138.716667
# 3242             KO WOOSUK             119.567857
# 5339            PARK GIWON             108.733333
# 153          BACK SEOYOUNG             106.100000
# 2923         JUNG SUNGHOON             106.100000
# 2558         HWANG DAESUNG              69.750000
# 3240            KO HYUNSOO              76.533333
# 7066        WANG JIAN ZONG              73.083333
# 3502          LEE YOUNGDAE              61.930952
# 3003           KARR RONALD              40.846032
# 3154           KIM SANGWON              65.683333
# 3143          KIM LAEYOUNG              60.466667
# 2972            KANG JIWON              54.814286
# 8395          YI SEUNGJUNE              48.200000
# 5340          PARK HAEWOOK              43.488095
# 2564        HWANG SEUNGGYE              44.389286
# 8461        YOUN MYUNGJUNE              40.683333
#
#       High Quality Patents Predicted by SEM  \
# 3483                              29.359524
# 8224                              19.338095
# 3164                              18.004762
# 6001                              14.550000
# 3242                               4.033333
# 5339                               3.800000
# 153                                2.550000
# 2923                               1.000000
# 2558                               9.833333
# 3240                               2.219048
# 7066                               0.000000
# 3502                               6.702381
# 3003                              17.918651
# 3154                               0.000000
# 3143                               4.400000
# 2972                               6.566667
# 8395                               3.666667
# 5340                               3.233333
# 2564                               1.519048
# 8461                               4.400000
#
#       High Quality Patents Predicted by ML       Total           label  \
# 3483                              6.250000  284.638095    LEE SEUNGMIN
# 8224                              5.759524  160.785714   YANG SUCKCHEL
# 3164                              5.759524  158.230952    KIM SEONWOOK
# 6001                              2.916667  156.183333     SEO HANBYUL
# 3242                              1.250000  124.851190       KO WOOSUK
# 5339                              0.833333  113.366667      PARK GIWON
# 153                               0.333333  108.983333   BACK SEOYOUNG
# 2923                              0.500000  107.600000   JUNG SUNGHOON
# 2558                              0.916667   80.500000   HWANG DAESUNG
# 3240                              0.976190   79.728571      KO HYUNSOO
# 7066                              0.000000   73.083333  WANG JIAN ZONG
# 3502                              2.442857   71.076190    LEE YOUNGDAE
# 3003                             10.750000   69.514683     KARR RONALD
# 3154                              0.000000   65.683333     KIM SANGWON
# 3143                              0.500000   65.366667    KIM LAEYOUNG
# 2972                              1.500000   62.880952      KANG JIWON
# 8395                              1.666667   53.533333    YI SEUNGJUNE
# 5340                              0.833333   47.554762    PARK HAEWOOK
# 2564                              0.666667   46.575000  HWANG SEUNGGYE
# 8461                              0.500000   45.583333  YOUN MYUNGJUNE
#
#              wrapped
# 3483    LEE SEUNGMIN
# 8224   YANG SUCKCHEL
# 3164    KIM SEONWOOK
# 6001     SEO HANBYUL
# 3242       KO WOOSUK
# 5339      PARK GIWON
# 153    BACK SEOYOUNG
# 2923   JUNG SUNGHOON
# 2558   HWANG DAESUNG
# 3240      KO HYUNSOO
# 7066  WANG JIAN ZONG
# 3502    LEE YOUNGDAE
# 3003     KARR RONALD
# 3154     KIM SANGWON
# 3143    KIM LAEYOUNG
# 2972      KANG JIWON
# 8395    YI SEUNGJUNE
# 5340    PARK HAEWOOK
# 2564  HWANG SEUNGGYE
# 8461  YOUN MYUNGJUNE

# %%
plot_top_entities_combined(
    dfs={"All Patents (2023-24)": df_all, "High Quality Patents Predicted by SEM": df_sem, "High Quality Patents Predicted by ML": df_ml},
    column="IPC Subclass",
    k_per_record=1,
    title="Top IPC Subclasses (3 Indicators)",
    ylabel="IPC Subclass",
    label_map=ipc_labels,
    label_mode="code+label",
    figsize=(16, 11)

)
# Out:
#     IPC Subclass  All Patents (2023-24)  \
# 80          G06F            2491.009524
# 122         H04W            2274.909524
# 84          G06Q            1956.252381
# 117         H04L            1310.592857
# 83          G06N             602.616667
# 114         H04B             307.366667
# 86          G06V             258.242857
# 99          G10L             167.716667
# 85          G06T              83.066667
# 72          G01S              57.783333
# 119         H04N              43.166667
# 94          G08G              19.700000
# 113         H03M              15.166667
# 118         H04M              18.750000
# 116         H04J              16.916667
# 102         G16H              16.850000
# 82          G06K              14.842857
# 90          G07F              13.666667
# 88          G07C               9.916667
# 29          B60W               8.650000
#
#      High Quality Patents Predicted by SEM  \
# 80                              149.200000
# 122                             155.116667
# 84                               52.450000
# 117                              78.200000
# 83                               12.166667
# 114                              18.166667
# 86                                6.666667
# 99                                0.333333
# 85                                1.833333
# 72                                4.500000
# 119                               3.500000
# 94                                0.000000
# 113                               3.000000
# 118                               0.000000
# 116                               0.666667
# 102                               0.000000
# 82                                0.450000
# 90                                1.166667
# 88                                0.000000
# 29                                0.000000
#
#      High Quality Patents Predicted by ML        Total  \
# 80                              56.333333  2696.542857
# 122                             38.666667  2468.692857
# 84                               6.666667  2015.369048
# 117                             24.666667  1413.459524
# 83                               1.833333   616.616667
# 114                              1.833333   327.366667
# 86                               3.250000   268.159524
# 99                               0.000000   168.050000
# 85                               0.250000    85.150000
# 72                               0.750000    63.033333
# 119                              0.250000    46.916667
# 94                               0.000000    19.700000
# 113                              1.000000    19.166667
# 118                              0.000000    18.750000
# 116                              0.333333    17.916667
# 102                              0.000000    16.850000
# 82                               0.000000    15.292857
# 90                               0.333333    15.166667
# 88                               0.000000     9.916667
# 29                               0.000000     8.650000
#
#                                                  label  \
# 80   G06F – Electric digital data processing (compu...
# 122             H04W – Wireless communication networks
# 84   G06Q – Data processing for admin/finance/commerce
# 117         H04L – Transmission of digital information
# 83   G06N – Computer systems based on specific mode...
# 114                      H04B – Transmission (general)
# 86   G06V – Image or video recognition / understanding
# 99      G10L – Speech analysis, synthesis, recognition
# 85   G06T – Image data processing or generation (ge...
# 72   G01S – Radio direction-finding, navigation, radar
# 119  H04N – Pictorial communication (television, vi...
# 94                      G08G – Traffic control systems
# 113        H03M – Coding, decoding, or code conversion
# 118                    H04M – Telephonic communication
# 116                     H04J – Multiplex communication
# 102     G16H – Health informatics (ICT for healthcare)
# 82   G06K – Recognition/presentation of data; recor...
# 90                 G07F – Coin-freed/vending apparatus
# 88   G07C – Time/attendance; machine work logging; ...
# 29        B60W – Conjoint control of vehicle sub-units
#
#                                                wrapped
# 80   G06F – Electric digital data processing\n(comp...
# 122             H04W – Wireless communication networks
# 84   G06Q – Data processing for\nadmin/finance/comm...
# 117        H04L – Transmission of digital\ninformation
# 83   G06N – Computer systems based on\nspecific mod...
# 114                      H04B – Transmission (general)
# 86   G06V – Image or video recognition /\nunderstan...
# 99     G10L – Speech analysis, synthesis,\nrecognition
# 85   G06T – Image data processing or\ngeneration (g...
# 72   G01S – Radio direction-finding,\nnavigation, r...
# 119  H04N – Pictorial communication\n(television, v...
# 94                      G08G – Traffic control systems
# 113       H03M – Coding, decoding, or code\nconversion
# 118                    H04M – Telephonic communication
# 116                     H04J – Multiplex communication
# 102    G16H – Health informatics (ICT for\nhealthcare)
# 82   G06K – Recognition/presentation of data;\nreco...
# 90                 G07F – Coin-freed/vending apparatus
# 88   G07C – Time/attendance; machine work\nlogging;...
# 29      B60W – Conjoint control of vehicle sub-\nunits

# %%
plot_top_entities_combined(
    dfs={"All Patents (2023-24)": df_all, "High Quality Patents Predicted by SEM": df_sem, "High Quality Patents Predicted by ML": df_ml},
    column="Publication Country Code",
    k_per_record=1,
    title="Top Countries (3 Indicators)",
    ylabel="Country",
    exclude={"WO"}                 # <- ignore WO
)
# Out:
#    Publication Country Code  All Patents (2023-24)  \
# 3                        CN                 5142.0
# 18                       US                 1710.0
# 11                       KR                  675.0
# 5                        EP                  522.0
# 9                        IN                  256.0
# 17                       TW                   49.0
# 10                       JP                   28.0
# 1                        BR                   14.0
# 16                       TR                   13.0
# 0                        AU                   13.0
# 14                       SG                   10.0
# 2                        CA                    5.0
# 12                       MX                    4.0
# 6                        GB                    4.0
# 8                        ID                    3.0
# 7                        HK                    3.0
# 13                       RU                    1.0
# 15                       TH                    1.0
# 4                        DE                    1.0
# 19                       VN                    1.0
#
#     High Quality Patents Predicted by SEM  \
# 3                                    39.0
# 18                                  422.0
# 11                                   14.0
# 5                                     4.0
# 9                                     0.0
# 17                                    0.0
# 10                                    1.0
# 1                                     0.0
# 16                                    0.0
# 0                                     0.0
# 14                                    0.0
# 2                                     0.0
# 12                                    0.0
# 6                                     0.0
# 8                                     0.0
# 7                                     0.0
# 13                                    0.0
# 15                                    0.0
# 4                                     0.0
# 19                                    0.0
#
#     High Quality Patents Predicted by ML   Total label wrapped
# 3                                    2.0  5183.0    CN      CN
# 18                                 110.0  2242.0    US      US
# 11                                  14.0   703.0    KR      KR
# 5                                    3.0   529.0    EP      EP
# 9                                    0.0   256.0    IN      IN
# 17                                   0.0    49.0    TW      TW
# 10                                   1.0    30.0    JP      JP
# 1                                    0.0    14.0    BR      BR
# 16                                   0.0    13.0    TR      TR
# 0                                    0.0    13.0    AU      AU
# 14                                   0.0    10.0    SG      SG
# 2                                    0.0     5.0    CA      CA
# 12                                   0.0     4.0    MX      MX
# 6                                    0.0     4.0    GB      GB
# 8                                    0.0     3.0    ID      ID
# 7                                    0.0     3.0    HK      HK
# 13                                   0.0     1.0    RU      RU
# 15                                   0.0     1.0    TH      TH
# 4                                    0.0     1.0    DE      DE
# 19                                   0.0     1.0    VN      VN

# %%
common_df = df_sem[df_sem["Publication Number"].isin(df_ml["Publication Number"])]

# %%
common_df.shape
# Out:
# (134, 20)

# %%
common_df.to_csv('Common_3.csv', index=False)
